# %%
# !python benchmark_tree.py --tree_method=gpu_hist
# Out:
# Generating dataset: 1000000 rows * 50 columns
# 0.25/0.75 test/train split
# Generate Time: 0.391268253326416 seconds
# DMatrix Start
# DMatrix Time: 2.835529088973999 seconds
# Training with 'gpu_hist'
# [0]	test-error:0.49854
# [1]	test-error:0.49973
# [2]	test-error:0.49986
# [3]	test-error:0.50068
# [4]	test-error:0.50022
# [5]	test-error:0.50068
# [6]	test-error:0.50160
# [7]	test-error:0.50172
# [8]	test-error:0.50114
# [9]	test-error:0.50034
# [10]	test-error:0.50025
# [11]	test-error:0.50006
# [12]	test-error:0.49988
# [13]	test-error:0.49902
# [14]	test-error:0.49916
# [15]	test-error:0.49931
# [16]	test-error:0.49948
# [17]	test-error:0.49962
# [18]	test-error:0.50004
# [19]	test-error:0.49955
# [20]	test-error:0.49855
# [21]	test-error:0.49886
# [22]	test-error:0.49921
# [23]	test-error:0.49871
# [24]	test-error:0.49874
# [25]	test-error:0.49887
# [26]	test-error:0.49961
# [27]	test-error:0.49914
# [28]	test-error:0.49892
# [29]	test-error:0.49931
# ...

# %%
# !python benchmark_tree.py --tree_method=hist
# Out:
# [08:10:29] 250000x50 matrix with 12500000 entries loaded from dtest.dm
# [08:10:29] 750000x50 matrix with 37500000 entries loaded from dtrain.dm
# Training with 'hist'
# [0]	test-error:0.49903
# [1]	test-error:0.49936
# [2]	test-error:0.50024
# [3]	test-error:0.50084
# [4]	test-error:0.49998
# [5]	test-error:0.50108
# [6]	test-error:0.49992
# [7]	test-error:0.49900
# [8]	test-error:0.49886
# [9]	test-error:0.49931
# [10]	test-error:0.49925
# [11]	test-error:0.49997
# [12]	test-error:0.50040
# [13]	test-error:0.50025
# [14]	test-error:0.49999
# [15]	test-error:0.50029
# [16]	test-error:0.49993
# [17]	test-error:0.49946
# [18]	test-error:0.49953
# [19]	test-error:0.49924
# [20]	test-error:0.49870
# [21]	test-error:0.49916
# [22]	test-error:0.49954
# [23]	test-error:0.50026
# [24]	test-error:0.50080
# [25]	test-error:0.50054
# [26]	test-error:0.50047
# [27]	test-error:0.50062
# [28]	test-error:0.50047
# [29]	test-error:0.50029
# [30]	test-error:0.50009
# [31]	test-error:0.49961
# ...
